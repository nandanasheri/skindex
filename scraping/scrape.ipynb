# %% [markdown]
# # Scraping Products from INCID Decoder

# %%
import requests
from bs4 import BeautifulSoup
import re
import json

# %%
exclude_links = set(["/products/new", "/products/create"])
all_product_links = set()

# %% [markdown]
# ## Scrape each page for varied results separately

# %%
url = f"https://incidecoder.com/products?page={3}"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
product_links = soup.find_all('a')    
for a in product_links:
    href = a.get("href")  # or a['href']
    if href.startswith("/products/") and href not in exclude_links and "discontinued" not in href:
        all_product_links.add(href)

# %%
# Scrape for when search result is put in for more number of results

url = "https://incidecoder.com/search?query=exfoliant"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
div = soup.find("div", class_="search-content")
product_links = div.find_all('a')    
for a in product_links:
    href = a.get("href")  # or a['href']
    if href.startswith("/products/") and href not in exclude_links and "discontinued" not in href:
        all_product_links.add(href)

# %%
print(len(all_product_links))
# Out:
# 6010

# %%
all_product_links
# Out:
# {'/products/la-mer-the-intensive-revitalizing-mask',
#  '/products/drgl-toner-sensitive',
#  '/products/uni-love-vegan-baby-cream',
#  '/products/baby-boo-bamboo-natural-baby-lotion',
#  '/products/the-ordinary-caffeine-solution-5-egcg',
#  '/products/dr-zenovia-skincare-10-benzoyl-peroxide-acne-cleanser',
#  '/products/wiley-body-hand-body-wash',
#  '/products/bio-essence-bio-water-foamy-cleanser',
#  '/products/olaplex-shampoo',
#  '/products/olay-prox-spot-fading-essence',
#  '/products/lemon-bottle-',
#  '/products/lacura-foaming-cleanser',
#  '/products/valuge-vansame-spray',
#  '/products/loye-mineral-foundation',
#  '/products/biosilk-silk-therapy-treatment',
#  '/products/tula-mineral-magic',
#  '/products/scinic-snail-aio-ampoule',
#  '/products/elmore-deep-nourishment-glycerin-body-lotion',
#  '/products/alverde-express-handcreme-bio-rosmarin-bio-zitronenmelisse',
#  '/products/bee-naturals-nail-cuticle-balm',
#  '/products/equate-beauty-foaming-scrub',
#  '/products/epionce-melanolyte-pigment-perfection-serum',
#  '/products/ve-cosmetics-primer',
#  '/products/bielenda-total-nail-pro-care-multifunctional-nail-conditioner-7in1',
#  '/products/rare-beauty-stay-vulnerable-melting-cream-blush',
#  '/products/bco-vitamin-c',
#  '/products/kylie-cosmetics-kybrow-gel',
#  '/products/tatcha-gentle-enzyme-cleanser-powder',
#  '/products/trilogy-rosehip-oil-antioxidant',
#  '/products/the-ordinary-whitening-cream-spf-35',
#  '/products/dr-sea-strengthening-mud-mask',
#  '/products/public-goods-shampoo-2',
#  '/products/verso-antioxidant-turmeric-booster',
#  '/products/sol-de-janeiro-brazilian-glossy-nourishing-oil',
#  '/products/lowengrip-the-serum-facial-serum',
#  '/products/topicals-faded-brightening-clearing-gel',
#  '/products/oaui-wave-spray',
#  '/products/dewytree-vitalizing-snail-serum',
#  '/products/rejuvi-healing-gel',
#  '/products/sesderma-sensyses-cleanser-lightening',
#  '/products/dr-yo-skin-cure-dna-salmon-gold-serum',
#  '/products/beauty-glam-retinol-serum',
#  '/products/not-your-mothers-bonding-shampoo-tough-love',
#  '/products/manetain-curl-cream',
#  '/products/bareskinlab-face-moisturiser',
#  '/products/nyx-hot-singles-eyeshadow',
#  '/products/farmasi-dr-c-tuna-green-vegan-mascara',
#  '/products/dodo-care-daysafe-lip-care',
#  '/products/prescription-vegan-vehicle-cleanser',
#  '/products/bath-body-works-vanilla-bean-noel',
#  '/products/raw-apothecary-shea-butter',
#  '/products/jeffree-star-cosmetics-supreme-gloss',
#  '/products/annique-charcoal-soap-bar',
#  '/products/clinique-super-rescue-antioxidant-night-moisturizer-for-very-dry-to-dry-skin',
#  '/products/evidence-skin-care-smooth-serum',
#  '/products/im-from-rice-serum',
#  '/products/omorovicza-moor-mud-cleanser',
#  '/products/ag-hair-curl-re-coil-curl-activator',
#  '/products/lancome-lash-idole-lash-lifting-volumizing-mascara',
#  '/products/rejuvaus-collagen-peptide-pores-fine-line-serum-rx',
#  '/products/mediheal-carrot-moisture-calming-pad',
#  '/products/dermalogica-phyto-replenish-body-oil',
#  '/products/the-beauty-crop-lip-treatment',
#  '/products/four-reasons-volume-mousse',
#  '/products/vaseline-lip-care-colour-care-mellow-rose',
#  '/products/barrier-glow-calming-glow-sunscreen',
#  '/products/le-petit-olivier-mousse-nettoyante',
#  '/products/syahirah-korean-secrets-hydra-soft-hydrating-toning-water',
#  '/products/fabyou-rice-mask-cleanser',
#  '/products/vgam-biome-mineral-komplements',
#  '/products/marc-anthony-instantly-thick-biotin-plump-lift-styling-cream',
#  '/products/nivea-urea-care-intensive-care-cream',
#  '/products/dermalogica-age-bright-spot-fader',
#  '/products/kaike-lip-frosting-conditioning-lip-balm',
#  '/products/rapunzel-of-sweden-hair-mask-for-hair-extensions',
#  '/products/bebio-cosmetics-volume-booster',
#  '/products/nuud-vegan-anti-odorant',
#  '/products/beauty-by-earth-coffee-bean-eye-cream',
#  '/products/use-haircare-wash',
#  '/products/skinceuticals-gentle-cleanser',
#  '/products/rugby-acne-medication-gel-10-acne-treatment',
#  '/products/la-mer-the-body-creme',
#  '/products/orgga-malaysia-daily-cleansing-powder-french-rose',
#  '/products/the-ordinary-marine-hyaluronics',
#  '/products/ani-k-makeup-corrector-bonita',
#  '/products/glow-hub-the-glow-giver-facial-serum',
#  '/products/carrot-stick-the-moisturizer',
#  '/products/amazon-basics-cleanser',
#  '/products/avivir-aloe-vera-womans-shave-mousse',
#  '/products/elfa-pharm-oherbal-mask-for-dry-and-damaged-hair-with-flax-extract',
#  '/products/ma-eye-cream-eye-cream',
#  '/products/erica-handcreme-sensitive',
#  '/products/ortho-dermatologics-altreno-tretinoin-lotion-0-05',
#  '/products/bliss-fabulips-vegan-balm',
#  '/products/ulta-joyful-jelly',
#  '/products/hyphen-barrier-care',
#  '/products/kelly-lemon-soap',
#  '/products/origins-zero-oil-oil-free-moisturiser',
#  '/products/heveblue-salmon-caring-centella-cream',
#  '/products/avene-milk-cleanser-2',
#  '/products/sephora-cucumber-eye-mask',
#  '/products/nyx-butter-gloss',
#  '/products/hello-glow-clarifying-toner-2',
#  '/products/neve-cosmetics-green-corrector',
#  '/products/anomaly-bonding-treatment-mask',
#  '/products/ray-face-scrub',
#  '/products/derma-eco-gentle-makeup-remover',
#  '/products/baby-chakra-natural-strengthening-baby-shampoo',
#  '/products/mjcare-cucumber-essence-mask',
#  '/products/clinique-clarifying-lotion-1',
#  '/products/it-cosmetics-bye-bye-pores-blush',
#  '/products/100-pure-vanilla-bean-shower-gel',
#  '/products/hair-energy-whole-blends-hair-shampoo',
#  '/products/sunnies-face-lip-glaze-peptide-lip-treatment',
#  '/products/rubys-organics-lipstick-berry',
#  '/products/dr-van-der-hoog-clay-mask-sea-algae-mask',
#  '/products/boots-expert-build-up-removal-shampoo',
#  '/products/medline-remedy-phytoplex-z-guard-paste',
#  '/products/cerave-moisturizing-cream-for-very-dry-skin-europe',
#  '/products/duetus-face-scrub',
#  '/products/murad-targeted-wrinkle-corrector',
#  '/products/neogen-white-truffle-laycure-oil-stick',
#  '/products/cosrx-the-alpha-arbutin-2-discoloration-care',
#  '/products/givenchy-prisme-primer-mattifying-primer',
#  '/products/mensome-retinol',
#  '/products/kopari-star-bright-vitamin-c-discoloration-correcting-serum',
#  '/products/cicarecipe-serum',
#  '/products/maria-nila-ocean-spray',
#  '/products/cetaphil-gentle-clear-clarifying-acne-cream-cleanser',
#  '/products/amazon-basics-daily-acne-control-cleanser-maximum-strength-10-benzoyl-peroxide-acne-medication',
#  '/products/clinique-superdefense-night',
#  '/products/waitrose-pure-pure-hydration-comforting-serum',
#  '/products/dp-dermaceuticals-retinal-active',
#  '/products/dewytree-mocha-peel-off-nose-pack',
#  '/products/olay-olay-total-effects-7-in-1-anti-aging-moisturiser-spf-15',
#  '/products/ainaa-cleanser',
#  '/products/heveblue-salmon-caring-centella-ampoule',
#  '/products/avene-d-pigment-brightening-serum',
#  '/products/aphogee-texture-treatment',
#  '/products/smoke-mirrors-lip-healing-infused-lip-oils',
#  '/products/boscia-vegan-collagen-booster',
#  '/products/uv-squad-sunscreen',
#  '/products/face-republic-aha-bha-toner-3',
#  '/products/mylan-tretinoin-cream',
#  '/products/dr-sante-anti-hair-loss-hair-mask',
#  '/products/w7-lip-jacket-lip-sealer',
#  '/products/perrigo-tretinoin-cream-usp',
#  '/products/bloom-and-blossom-legs-eleven-cooling-leg-serum',
#  '/products/farmona-professional-acid-tech-glycolic-acid-50-shikimic-acid-10',
#  '/products/hoito-aha-bha-tonic',
#  '/products/alterra-tinted-daycream',
#  '/products/sanoflore-aqua-merveilleuse',
#  '/products/voloom-dry-shampoo',
#  '/products/ayunche-enrich-bonding-shampoo',
#  '/products/jamaican-mango-lime-black-castor-oil-peppermint-oil',
#  '/products/beaute-recipe-rose-water-tender-cleansing-water',
#  '/products/roots-sensitive-shampoo',
#  '/products/telse-black-bean-ceramide-cream',
#  '/products/the-inkey-list-turmeric-cream-moisturiser',
#  '/products/curl-girl-nordic-curling-gel-curl-activator',
#  '/products/bepanthol-balm',
#  '/products/mirabella-sheet-mask',
#  '/products/watsons-water-bomb',
#  '/products/war-paint-tinted-moisturizer',
#  '/products/kms-sea-salt-spray',
#  '/products/shea-moisture-raw-shea-butter-deep-moisturizing-masque',
#  '/products/bali-balm-cinnamon-burnt-orange-lip-balm',
#  '/products/sebocalm-active-moisturizer',
#  '/products/la-mer-the-tonic',
#  '/products/the-oozoo-oozoo-face-injection-mask-hydro-lift',
#  '/products/little-twig-shampoo-shampoo',
#  '/products/sanlivna-snail-mucin-96',
#  '/products/mille-perfect-matte-longwear-cushion',
#  '/products/daybird-tinted-skincare',
#  '/products/cf-ceuticals-tetra-serum',
#  '/products/olay-spotless-serum',
#  '/products/cetaphil-moisturizer-lotion-cetaphil',
#  '/products/dr-brandon-white-expert-clinical-acne-care-solution-body-care',
#  '/products/epionce-enriched-body-cream',
#  '/products/gold-bond-crepe-corrector',
#  '/products/rare-beauty-stay-vulnerable-melting-blush',
#  '/products/mediterranean-spirit-vitamin-c',
#  '/products/himalaya-damage-repair-shampoo',
#  '/products/kruidvat-sensitive-handzeep',
#  '/products/ny-bae-liquid-lipstick',
#  '/products/rare-beauty-warm-wishes-effortless-bronzer-stick',
#  '/products/the-body-shop-body-shop-hemp-body-butter',
#  '/products/now-solutions-vegetable-glycerin',
#  '/products/skintra-c-the-light-serum-z-witamina-c-tetra',
#  '/products/equate-beauty-acne-was-10-benzoyl-peroxide',
#  '/products/dermafix-brightening-cleanser-minimising-uneven-skin-tone-hyperpigmentation',
#  '/products/eco-styler-krystal-styling-gel',
#  '/products/penaten-shampoo',
#  '/products/ccsd-rx-reverse-tretinoin-0-05',
#  '/products/neutrogena-hidratante-corporal-neutrogena-body-care-r-intensive-hidrata-suaviza',
#  '/products/bio-essence-bio-water-sensitive-ph',
#  '/products/vendela-instant-glow',
#  '/products/roromendut-green-jelly',
#  '/products/clinique-clinique-id-bb-gel-pores-uneven-texture-pre-assembled-kit',
#  '/products/ilso-clean-mud-cream',
#  '/products/beauty-pie-brazilian-lime-fig-leaves-tea',
#  '/products/olay-gentle-cleansing-balm',
#  '/products/dagoderma-scar-emulgel',
#  '/products/jarte-beauty-sunscreen-spray',
#  '/products/isana-korean-skincare-moisturizing-face-mask',
#  '/products/lanbena-mung-bean-clay-mask',
#  '/products/m3-turmeric-scrub',
#  '/products/we-are-paradox-volume-shampoo',
#  '/products/its-a-10-silk-express-miracle-silk-shampoo',
#  '/products/7days-liquid-concealer',
#  '/products/bio-vegane-tagescreme-bio-acai',
#  '/products/freshity-milk-lotion',
#  '/products/south-beach-skincare-body-butter',
#  '/products/glamory-serum',
#  '/products/essano-fragrance-free-deodorant',
#  '/products/ps-hyaluronic-acid-micellar-water-micellar-water',
#  '/products/silk-glycolic-lactic-face-body-scrub-10',
#  '/products/olivia-care-rosewater-glycerin-body-face-mist',
#  '/products/catrice-lip-lovin-smoothing-lip-scrub',
#  '/products/alverde-hydro-korperlotion',
#  '/products/schwarzkopf-simply-color-2',
#  '/products/body-me-bornyugtato-body-cleanser',
#  '/products/boots-cucumber-moisturising-cream',
#  '/products/nature-by-canus-fragrance-free-lotion',
#  '/products/neutrogena-curvuma-cleanser',
#  '/products/neutrogena-advanced-acne-serum',
#  '/products/dr-michelle-copeland-pigment-formula',
#  '/products/eyenlip-hydrogel-eye-patch-salmon-oil-peptide',
#  '/products/dr-eckstein-azulen-paste',
#  '/products/sooae-hydrating-cucumber-mask',
#  '/products/medik8-advanced-day-eye-protect-eye-cream',
#  '/products/frezyderm-acne-control',
#  '/products/junggluck-lash-serum',
#  '/products/dermalogica-awaken-peptide-depuffing-eye-gel',
#  '/products/lanbena-nose-plants-pore-strips-2',
#  '/products/farmasi-fcc-cc-cream-tinted-moisturizer-2',
#  '/products/soap-glory-breakfast-scrub',
#  '/products/lacoupe-orgnx-brazilian-keratin-complex-masque',
#  '/products/intermed-luxurious-scrub',
#  '/products/skin-co-cleanser',
#  '/products/the-inkey-list-retinol',
#  '/products/mia-cosmetics-paris-nail-polish-remover',
#  '/products/face-botox-serum',
#  '/products/cjs-butter-shea-butter-balm',
#  '/products/chitocare-medical-healing-spray',
#  '/products/hair-syrup-lemon-aid',
#  '/products/bepanthen-anti-scar',
#  '/products/gladskin-body-wash',
#  '/products/skin-control-pimple-patch',
#  '/products/zero-frizz-keratin-serum',
#  '/products/ecoslay-lemon-buttercream',
#  '/products/o-m-hair-color',
#  '/products/kvd-vegan-beauty-nourishing-vegan-butter-lipstick',
#  '/products/dr-sante-keratin-shampoo',
#  '/products/mielle-babassu-conditioning-shampoo',
#  '/products/redken-acidic-bonding-curls-shampoo',
#  '/products/opi-nail-envy-nail-strengthener-original-formula',
#  '/products/la-mer-genaissance-de-la-mer-the-serum-essence-2',
#  '/products/ilcsi-lightening-cream',
#  '/products/radiant-cosmetics-nail-growth-oil',
#  '/products/skin-actives-collagen-serum',
#  '/products/lumin-charcoal-face-scrub',
#  '/products/rosense-foaming-cleanser',
#  '/products/boots-spf-brightening-eye-cream-spf-30',
#  '/products/kinky-curl-curl-custard',
#  '/products/eveline-cosmetics-brazilian-body-cc-cream',
#  '/products/paulas-choice-resist-anti-aging-eye-gel',
#  '/products/hivado-thick-and-full-shampoo',
#  '/products/blue-atlas-vitamin-c',
#  '/products/volition-beauty-turmeric-brightening-polish',
#  '/products/martiderm-mineral-d',
#  '/products/touch-plant-collagen-q10-moisturizer',
#  '/products/la-mer-the-regenerating-serum',
#  '/products/bodhi-beverly-hills-passion-eye-anytime-eye-cream',
#  '/products/cantabria-labs-biretix-mask',
#  '/products/sunatoria-black-mask-charcoal-peel-off-mask',
#  '/products/w7-just-tinted-natural-skin-tinted-moisturiser',
#  '/products/cereve-foaming-cleanser-bar',
#  '/products/dermalogica-powerbright-dark-spot-peel-2',
#  '/products/baiobay-lip-balm',
#  '/products/anteage-cleanser',
#  '/products/the-skinscience-company-carrot-seed-butter',
#  '/products/advanced-clinicals-plant-based-collagen',
#  '/products/buttah-charcoal-detox-mask',
#  '/products/fairtone-cream',
#  '/products/dermies-pimple-body-mist',
#  '/products/cute-press-ci-lab-sensitiv-moisture-repair-first-serum',
#  '/products/the-inkey-list-turmeric-moisturizer-2021',
#  '/products/monte-luna-scalp-scrub',
#  '/products/baroness-collagen-mask-sheet',
#  '/products/redken-pillow-proof-blow-dry-two-day-extender-dry-shampoo',
#  '/products/epionce-renewal-body-lotion',
#  '/products/eco-care-handsoap-pomegranate',
#  '/products/scinic-snail-matrix-essence',
#  '/products/filter-by-molly-mae-tanning-mousse',
#  '/products/coxir-toner',
#  '/products/synergy-therm-azelaic-acid',
#  '/products/etude-house-lemon-mask',
#  '/products/em-cosmetics-lip-cushion-tinted-lip-luminizer',
#  '/products/o-skin-care-active-moisturizer',
#  '/products/clear-skin-days-blemish-repair-paste',
#  '/products/dennis-knudsen-eye-gel',
#  '/products/ren-flash-rinse-1-minute-facial',
#  '/products/eucerin-anti-pigment-ultraleve',
#  '/products/kahi-aqua-balm',
#  '/products/mehron-barrier-spray',
#  '/products/bioaqua-lash-serum',
#  '/products/skinkick-daily-exfoliant-cleanser',
#  '/products/twilash-by-dly-lash-shampoo',
#  '/products/dermalogica-map-15-regenerator',
#  '/products/anua-heartleaf-77-soothing-toner-korean-version',
#  '/products/chicco-tooth-paste',
#  '/products/mielle-moisture-rx-hawaiian-ginger-styling-gel',
#  '/products/clinique-eye-shadow-pinks',
#  '/products/the-ordinary-saccharomyces-ferment-30-milky-toner',
#  '/products/barrier-glow-calming-moisture-glow-cream',
#  '/products/catrice-curl-it-volume-curl-mascara',
#  '/products/nutrius-berry-bliss-brazilian-body-butter-cream',
#  '/products/tatcha-the-essence',
#  '/products/too-faced-lip-injection-lip-gloss',
#  '/products/lirene-anticellulite-treatment',
#  '/products/farmona-professional-acid-tech-mandelic-acid-40',
#  '/products/dr-konrad-ichtacolor-r-paste',
#  '/products/target-pro-by-watsons-essential-hot-cleansing-gel',
#  '/products/flexitol-nail-revitaliser-gel',
#  '/products/lirene-vitamin-shot-3in1-vitamin-micellar-water',
#  '/products/rare-beauty-sincerely-me-eyeshadow-palette',
#  '/products/lucens-umbria-color',
#  '/products/salt-by-hendrix-eye-babe-under-eye-creme',
#  '/products/elzin-plant-tuiazin',
#  '/products/rimmel-london-nail-nurse-stronger-nail',
#  '/products/korika-korean-heritage-marine-stem-cells',
#  '/products/alverde-hydro-primer',
#  '/products/shira-organic-shir-organic-pure-botanics-chamomille-toner',
#  '/products/my-sunscreen',
#  '/products/equate-beauty-gentle-lotion',
#  '/products/australian-bodycare-body-scrub',
#  '/products/sugar-rush-cake-butter',
#  '/products/sgxnyc-dry-touch',
#  '/products/visible-ingredients-spray-away-persimmon-sanitizing-spray',
#  '/products/earth-tu-face-face-wash',
#  '/products/eximia-aqua-mat-exfoliant',
#  '/products/snp-prep-peptaronic-ampoule-korean-sheet-mask',
#  '/products/the-ordinary-squalane-cleanser',
#  '/products/bepanthen-cream',
#  '/products/dermaplus-eye-care-cream-eyelighten-hyperpigmentation',
#  '/products/catrice-lip-lovin-caring-lip-serum',
#  '/products/laikou-men-facial-toner',
#  '/products/riversol-the-corrector',
#  '/products/l-a-girl-hd-pro-corrector-concealer-green-corrector',
#  '/products/neutrogena-mineral-stick-sunscreen',
#  '/products/clinique-almost-lipstick',
#  '/products/texture-id-low-porosity-curl-defining-cream',
#  '/products/dermatica-tretinoin-0-1',
#  '/products/mineraline-bha-night-cream',
#  '/products/abnomaly-petrowhat-milk',
#  '/products/catrice-hydro-supercharged-serum',
#  '/products/cerave-oil-control-moisturizing-gel-cream',
#  '/products/natures-nourishment-facial-toner',
#  '/products/revox-japanese-ritual-face-cream-light-texture',
#  '/products/mamaearth-ubtan-nourishing-hair-removal-cream',
#  '/products/first-aid-beauty-hello-fab-pores-be-gone-matte-primer',
#  '/products/aloe-vera-australia-aloe-vera-conditioner',
#  '/products/piz-buin-spf-50',
#  '/products/babaria-retinol',
#  '/products/loli-chia-carrot-brulee',
#  '/products/organic-traveller-sunblock',
#  '/products/natura-night-serum-for-oil-control-and-pores-refiner',
#  '/products/aloe-247-organic-aloe-gel',
#  '/products/elyns-lab-lip-hack-lip-balm',
#  '/products/nyk1-lash-serum',
#  '/products/simple-foaming-cleanser',
#  '/products/leegeehaam-enzyme-wash',
#  '/products/schwarzkopf-simply-color',
#  '/products/orjena-collagen-mask-sheet',
#  '/products/lashed-md-lash-serum',
#  '/products/kristen-ess-thickening-spray',
#  '/products/zenutrients-baby-love-calendula-gentle-baby-conditioner',
#  '/products/rare-beauty-soft-pinch-tinted-lip-oil',
#  '/products/pirkka-body',
#  '/products/royaute-pigment-control',
#  '/products/diadermine-toner',
#  '/products/illustrious-essence-mediterranean-wash',
#  '/products/eco-elio-sunscreen-spf50',
#  '/products/solaris-retinol',
#  '/products/rejuvaskin-scar-esthetique',
#  '/products/hyphen-lip',
#  '/products/mehron-liquid-makeup',
#  '/products/pure-care-vitamin-a',
#  '/products/body-prescriptions-body-butter',
#  '/products/quickfx-tinted-moisturizer',
#  '/products/yves-rocher-liquid-concealer',
#  '/products/prima-oligo-foaming-cleanser',
#  '/products/logona-hyaluron-hydro-fluid',
#  '/products/organic-shop-body-scrub-organic-mango-sugar',
#  '/products/bond-bar-bonding-technology-lightener',
#  '/products/lakme-micellar-water',
#  '/products/cerave-foaming-cleanser-7',
#  '/products/mielle-pomegranate-honey-moisturizing-and-detangling-shampoo',
#  '/products/acnil-mousse-cleanser',
#  '/products/happy-skin-generation-happy-skin-stay-fresh-blurring-skin-tint',
#  '/products/bioderma-photoderm-leb-spf-30',
#  '/products/olay-luminous-niacinamide-vitamin-c-super-serum',
#  '/products/dr-organic-organic-hemp-oil-lip-serum',
#  '/products/nuse-mousse-lingual',
#  '/products/bio-oil-lip-butter',
#  '/products/sisley-energizing-foaming-exfoliant',
#  '/products/clear-2-perfection-shampoo',
#  '/products/blossom-kochhar-aroma-magic-carrot-sunscreen',
#  '/products/la-mer-the-lip-volumizer',
#  '/products/honest-glow-fragrance-free-sunscreen',
#  '/products/neals-yard-remedies-lemon-coriander-deodorant',
#  '/products/mdacne-active-moisturizer',
#  '/products/differin-gel',
#  '/products/cerave-ultra-light-moisturizing-gel',
#  '/products/alterra-carrot-cake-blush',
#  '/products/de-maf-cream',
#  '/products/authoriderm-hydro-derma-serum',
#  '/products/keune-tinta-color',
#  '/products/northstarx-tretinoin-cream-usp-0-05',
#  '/products/midha-rice-serum',
#  '/products/divi-conditioner',
#  '/products/revox-b77-japanese-routine-crema-viso-texture-leggera',
#  '/products/mielle-organics-pomegranate-honey-curl-smoothie',
#  '/products/heveblue-salmon-caring-centella-bubble-cleanser',
#  '/products/eco-styler-black-castor-oil-and-flax-seed-oil-styling-gel',
#  '/products/shea-moisture-raw-shea-butter-extra-moisture-detangler-2',
#  '/products/aquanil-cleanser',
#  '/products/the-ordinary-gf-15-serum',
#  '/products/isana-schaumbad-berry-love',
#  '/products/neutrogena-nourishing-eyeliner',
#  '/products/sunstop-silk-sunscreen-2',
#  '/products/mielle-mango-tulsi-nourishing-instant-3-in-1-serum',
#  '/products/eucerin-aquaphor-lip-repair-stick-for-dry-lips',
#  '/products/tatcha-the-rice-wash-soft-cream-cleanser',
#  '/products/formless-beauty-silk-moisturizer',
#  '/products/redkin-acidic-bonding-curls',
#  '/products/innoxa-hydrating-primer',
#  '/products/drs-secret-sunscreen',
#  '/products/primera-alpine-berry-water-cream',
#  '/products/jardinpeau-intensive-salmon-dna-ampoule',
#  '/products/foreverskin-salmon-cheek-patch',
#  '/products/s-u-n-d-a-y-smooth-shampoo',
#  '/products/collistar-pure-elastine-actif-pure',
#  '/products/the-body-shop-japanese-cherry-blossom-deodorant-roll-on',
#  '/products/rosemix-natural-cosmetics-snail-cream',
#  '/products/the-ordinary-100-plant-derived-squalane-2',
#  '/products/jamaican-mango-lime-shampoo',
#  '/products/femfresh-soothing-wash',
#  '/products/plant-apothecary-start-happy-body-wash',
#  '/products/l-occitane-milk-concentrate',
#  '/products/hiskin-crazy-hair-laminating-jelly-for-low-porosity-hair-forest-fruit',
#  '/products/nivea-men-men-deep-moisturiser',
#  '/products/cute-press-ci-lab-sensitiv-moisture-repair-barrier-cream',
#  '/products/sidmool-pure-snail-essence',
#  '/products/cetaphil-dermacontrol-oil-control-foam-wash',
#  '/products/clinique-full-potential-lips',
#  '/products/kiehls-damage-repairing-rehydrating-shampoo',
#  '/products/ciele-liquid-blush',
#  '/products/bio-essence-bio-bounce-night-mask',
#  '/products/natures-holistics-vitamin-c',
#  '/products/nakolwethu-spf-50',
#  '/products/paulas-choice-defense-antioxidant-pore-purifier',
#  '/products/neutrogena-gel-de-limpeza-profunda-neutrogena-deep-clean',
#  '/products/drgl-cleanser-acne',
#  '/products/taab-serum-snail',
#  '/products/quickfx-pimple-eraser-2023',
#  '/products/the-glow-fairy-retinol-body-glow-wand',
#  '/products/sephora-collection-targeted-pores-serum-with-bha-pha',
#  '/products/million-colors-primer',
#  '/products/cerave-ceramides-eye-repair-cream-for-dark-circles',
#  '/products/pure-simple-pure-skin-face-lotion',
#  '/products/olay-bump-erasing',
#  '/products/green-leaf-naturals-toner',
#  '/products/cetaphil-redness-relieving',
#  '/products/aussie-hair-hug-reconstructor-hair-mask',
#  '/products/bio-balance-discoloration-free-lumiskin-4',
#  '/products/boost-focus-oil-rosemary-oil',
#  '/products/butentity-cute-blue-indigo-soap',
#  '/products/cremo-thickening-paste',
#  '/products/e45-foaming-cleanser',
#  '/products/clean-clear-lemon-exfoliating-slices',
#  '/products/elementre-micellar-water-2-glycerin',
#  '/products/neutrogena-healthy-lengths-mascara',
#  '/products/aveda-dry-remedy-shampoo',
#  '/products/neutrogena-hydro-boost-5',
#  '/products/bio-essence-bio-water-b5-pore-minimizer',
#  '/products/oshea-face-wash',
#  '/products/b-fresh-vitamin-sea',
#  '/products/only-skin-scrub',
#  '/products/la-mer-the-treatment-lotion',
#  '/products/lorac-pro-skin-glass-skin-primer',
#  '/products/resibio-serum',
#  '/products/the-body-shop-shea-soap',
#  '/products/cerave-baby-moisturizing-lotion-4',
#  '/products/renuar-maqui-berry',
#  '/products/altk-beauty-tinted-serum',
#  '/products/acretin-tretinoin-0-025-cream',
#  '/products/tatcha-indigo-overnight-repair-4',
#  '/products/deva-nourshing-care',
#  '/products/young-solution-wash-up-face-wash',
#  '/products/moroccanoil-volumizing-mousse-2',
#  '/products/natura-bisse-cleanser',
#  '/products/aesop-conditioner',
#  '/products/thrive-causemetics-toner',
#  '/products/karin-herzog-mild-scrub',
#  '/products/rodan-and-fields-lash-boost',
#  '/products/estgen-cleansing-liquid',
#  '/products/kallos-kjmn-silk-shampoo',
#  '/products/drunk-elephant-b-hydra-intensive-hydration-serum',
#  '/products/meco-lightening-cream',
#  '/products/equate-beauty-acne-facial-cleansing-wash-10-benzoyl-peroxide',
#  '/products/panthophil-anti-dry-wash',
#  '/products/vivier-exfoliant-forte',
#  '/products/neutrogena-neutrogena-shampoo-anti-residue-formula',
#  '/products/saeed-ghani-tinted-sunscreen',
#  '/products/tatcha-the-silk-sunscreen-spf-50',
#  '/products/disciple-balancing-mist',
#  '/products/pure-care-anti-pimple-patches',
#  '/products/wifi-care-shampoo-reparador-widi-care-phytomanga',
#  '/products/phique-conditioner',
#  '/products/the-body-shop-vitamin-e',
#  '/products/asp-clear-nail-builder',
#  '/products/lancome-hydrogel-sheet-mask',
#  '/products/newsha-treatment',
#  '/products/sol-de-janeiro-brazilian-bum-bum-cream-2',
#  '/products/earth-harbor-siren-silk',
#  '/products/alissa-beaute-cleansing-mousse',
#  '/products/starface-hydro-star-r',
#  '/products/afrolocke-conditioner',
#  '/products/the-skinscience-company-ucuuba-butter',
#  '/products/glytone-dark-spot-corrector',
#  '/products/tahnyc-silk',
#  '/products/baby-dove-baby-dove-caring-by-nature-hypoallergenic-baby-oil',
#  '/products/mulondon-fragrance-free-moisturiser',
#  '/products/pure-korean-tropical-fruit-mask-pack-multi-vitamin-strawberry',
#  '/products/lirene-natura-eco-illuminating-foundation',
#  '/products/dermol-cream',
#  '/products/hot-sorry-niacinamide-b3-essence',
#  '/products/sheglam-peachy-clean-makeup-removal-wipes',
#  '/products/buttah-cleanser',
#  '/products/nail-tek-strengthen',
#  '/products/scinic-snail-matrix-skin',
#  '/products/paulas-choice-power-berry-serum-2',
#  '/products/living-proof-weightless-spray',
#  '/products/sooae-donkey-milk',
#  '/products/sei-bella-mineral-foundation',
#  '/products/tocobo-lemon-sugar-lip-scrub',
#  '/products/aestura-theracne365-bubble-cleanser',
#  '/products/mutha-cream',
#  '/products/shea-moisture-raw-shea-butter-deep-treatment-masque',
#  '/products/boom-stick-color',
#  '/products/organic-shop-organic-shop-golden-orchid-colour-conditioner',
#  '/products/uriage-gentle-deodorant',
#  '/products/zena-smooth-shampoo',
#  '/products/mielle-pre-shampoo-treatment-with-mongongo-oil',
#  '/products/cute-press-asta-gold-oil-essence',
#  '/products/ambi-even-clear-advanced-fade-cream-hydroquinone-free-hyperpigmentation-treatment-stubborn-dark-spot',
#  '/products/hello-body-rose-velvet',
#  '/products/kueshi-lemon-body-milk',
#  '/products/dphue-gloss',
#  '/products/matrix-so-long-damage-shampoo',
#  '/products/skin-cafe-toner',
#  '/products/la-mer-the-rejuvinating-night-cream-2024',
#  '/products/cetaphil-ceramide-serum',
#  '/products/attirance-micellar-water',
#  '/products/feev-hyper-hydro-serum',
#  '/products/ps-japanese-match-tea-cream-mask',
#  '/products/dollar-shave-club-acne-eraser',
#  '/products/clear-nose-facial-matte-serum-oil-free',
#  '/products/esfolio-hydrogel-snail-mask',
#  '/products/shea-moisture-high-porosity-moisture-replenish-masque',
#  '/products/ik-skin-perfection-silk',
#  '/products/t444z-hair-products-hair-food',
#  '/products/heveblue-salmon-caring-centella-ampoule-2',
#  '/products/aiken-pimple-cream',
#  '/products/eltraderm-cucumber-hydrating-mask',
#  '/products/halea-refreshing-toner',
#  '/products/shiseido-tsubaki-damage-care-conditioner',
#  '/products/prose-shampoo-2',
#  '/products/rosental-organics-volume-shampoo',
#  '/products/la-mer-the-lifting-and-firming-mask',
#  '/products/ponds-hydra-active',
#  '/products/veralab-leg-booster',
#  '/products/onsen-secret-bodylotion-organic-fusion-acai-berrie-and-japanese-green-tea',
#  '/products/find-sheet-mask-purifying',
#  '/products/borotalco-pure',
#  '/products/panoxyl-acne-creamy-wash-benzoyl-peroxide-4-daily-control',
#  '/products/reitzers-aqueous-cream-glycerin-soap',
#  '/products/lanbena-nose-plants-pore-strips',
#  '/products/sephora-collection-face-mask-rose-face-mask',
#  '/products/margaret-dabbs-london-nail-cuticle-treatment',
#  '/products/protex-baby',
#  '/products/heveblue-salmon-care-centella-toner',
#  '/products/labochy-shampoo',
#  '/products/cetaphil-moisturizing-cream-for-very-dry-to-dry-sensitive-skin',
#  '/products/alima-pure-smooth-prime',
#  '/products/cv-rose-reinigungsol',
#  '/products/hada-labo-aqua-mask-2',
#  '/products/mielle-organics-mango-tulsi-nourishing-conditioner',
#  '/products/cuura-on-the-spot-acne-spot-treatment',
#  '/products/body-me-problemamegoldo-body-treatment',
#  '/products/tindigo-hydro-queen',
#  '/products/cerave-feuchtigkeitscreme-moisturizing-cream-eu-version',
#  '/products/omorovicza-ultramoor-mud-mask-2',
#  '/products/syoss-keratin-taming-lotion',
#  '/products/deva-curl-bleave-in-miracle-curl-plumper',
#  '/products/tatcha-the-clarifying-clay-mask',
#  '/products/celenes-cleansing-foaming-gel',
#  '/products/medik8-c-tetra-lipid-c-radiance-serum',
#  '/products/david-mallett-australian-salt-spray',
#  '/products/olivia-quido-skincare-spot-eraser',
#  '/products/sanfe-intimate-lightening-serum',
#  '/products/pink-by-pure-beauty-bye-bye-pores-cleansing-foam',
#  '/products/it-cosmetics-bye-bye-pores-poreless-finish-airbrush-powder',
#  '/products/ogx-ever-straightening-plus-brazilian-keratin-shampoo',
#  '/products/neutrogena-protetor-solar-neutrogena-sun-fresh-fps50',
#  '/products/cute-press-ci-lab-sensitiv-moisture-repair-body-lotion',
#  '/products/esfolio-aha-bha-toner',
#  '/products/reequil-skin-radiance-cream-for-hyperpigmentation',
#  '/products/be-minimalist-sunscreen-2',
#  '/products/nuxe-very-rose-rose-lip-balm',
#  '/products/shea-moisture-raw-shea-butter-moisturizing-detangler',
#  '/products/parachute-coconut-oil-parachute-argan-oil',
#  '/products/american-crew-grooming-spray',
#  '/products/lafalova-dna-salmon-bright-glow-moisturizer',
#  '/products/kosette-salt-scalp-scrub',
#  '/products/23-years-old-peeling-treatment',
#  '/products/dermatica-0-1-tretinoin-cream',
#  '/products/foresta-rose-essence',
#  '/products/saaren-taika-shampoo',
#  '/products/cute-press-pure-origin-white-oil-control-facial-foam',
#  '/products/masquebar-foil-sheet-mask',
#  '/products/shea-moisture-sheamoisture-low-porosity-weightless-hydrating-shampoo',
#  '/products/kruidvat-originals-scrubmasker-charcoal',
#  '/products/organic-shop-organic-coffee-silk-rejuvenating-face-mask',
#  '/products/hygienelab-conditioner',
#  '/products/nuud-vegan-anti-odorant-2',
#  '/products/avene-radiance-serum-serum-eclat',
#  '/products/olleskin-lightening-soap',
#  '/products/stbotanica-go-anti-hair-fall-hair-shampoo',
#  '/products/cute-press-0-silicone-detoxifying-shampoo',
#  '/products/ogx-thick-full-volumising-biotin-collagen-shampoo-for-fine-hair',
#  '/products/dr-barbara-sturm-cleanser',
#  '/products/lash-treat-rose-infused-lash-serum',
#  '/products/isdin-pigment-expert',
#  '/products/dr-jart-ceramidin-liquid',
#  '/products/virtue-damage-serum',
#  '/products/keff-sensitive-cream',
#  '/products/sephora-collection-face-mask-the-golden-mask',
#  '/products/pantene-pro-v-aqua-light',
#  '/products/tata-harper-resurfacing-mask',
#  '/products/philosophy-pure-grace',
#  '/products/ekel-charcoal-foam-cleanser',
#  '/products/bare-anatomy-damage-repair-shampoo',
#  '/products/african-extracts-spot-treatment',
#  '/products/m3-naturals-himalayan-salt-scrub',
#  '/products/redken-acidic-bonding-concentrate-intensive-treatment',
#  '/products/dermalogica-active-moist',
#  '/products/krauterhof-snail-extract-gel',
#  '/products/differin-maximum-strength-acne-foaming-cleanser-10-benzoyl-peroxide',
#  '/products/me-bha-toner',
#  '/products/vitamasques-jade-sheet-mask',
#  '/products/aestura-a-cica-stress-relief-cream-essence',
#  '/products/oars-and-alps-face-wash',
#  '/products/esqa-lip-gloss',
#  '/products/colorbar-lip-gloss',
#  '/products/tatcha-the-liquid-silk-canvas-featherweight-protective-primer',
#  '/products/aloe-pura-organic-aloe-vera-gel',
#  '/products/cetaphil-moisturizing-lotion',
#  '/products/dermalogica-precleanse',
#  '/products/dermalure-acid-neutralizer',
#  '/products/sofnon-tsaio-rose-nectar-wash-removal-mousse',
#  '/products/skinceuticals-triple-lipid-restore-2-4-2',
#  '/products/haore-sunscreen',
#  '/products/the-glow-pot-cucumber-cleanser',
#  '/products/astral-cream',
#  '/products/teenilicious-acne-face-cleanser-with-benzoyl-peroxide-and-witch-hazel-extract',
#  '/products/cosrx-pimple-patch',
#  '/products/nivea-sun-protect-sensitive',
#  '/products/omorovicza-mineral-touch',
#  '/products/nykaa-japanese-cherry-blossom-shower-gel',
#  '/products/miracle-10-mask',
#  '/products/indola-color-shampoo',
#  '/products/tatcha-the-serum-stick',
#  '/products/pannobase-retinol',
#  '/products/barbasol-thick-and-rich-shaving-cream',
#  '/products/supergoop-mineral-mattescreen-100-mineral-sunscreen',
#  '/products/dermalogica-age-smart-biolumin-c-serum',
#  '/products/episoft-spf-50',
#  '/products/jicott-caviar-real-mask-ampoule-mask',
#  '/products/frank-body-hydrating-body-wash',
#  '/products/aestura-atobarrier365-ceramide-hydro-soothing-cream',
#  '/products/cellmen-face',
#  '/products/clarins-men-smooth-shave',
#  '/products/marina-miracle-flower-berry-essence',
#  '/products/advanced-clinicals-turmeric-oil',
#  '/products/flora-and-curl-flora-curl-sweet-hibiscus-curl-defining-gel',
#  '/products/nassif-md-gentle-cleanser',
#  '/products/clear-nose-uv-sun-serum-spf50-pa-3',
#  '/products/organic-shop-organic-algae-sea-mud',
#  '/products/natural-world-brazilian-keratin-hair-treatment-oil',
#  '/products/chi-keratin-reconstructing-conditioner',
#  '/products/etat-pur-retinol',
#  '/products/open-formula-argan-oil-100-argan-oil',
#  '/products/epionce-renewal-calming-cream-2',
#  '/products/missha-damage-hair-therapy-shampoo',
#  '/products/apieu-goblin-blackhead-peel-off-nose-pack',
#  '/products/schwarzkopf-professional-bc-bonacure-oil-miracle-argan-oil',
#  '/products/trust-my-sister-hair-mask-5-in-1-high-porosity',
#  '/products/dr-wongs-lightening-lotion',
#  '/products/creamy-retinol',
#  '/products/derma-eco-cleansing-gel',
#  '/products/clinique-even-better-essence-lotion-combo-oily-skin',
#  '/products/revlon-nail-enamel',
#  '/products/aestura-atobarrier-365-lotion-2',
#  '/products/mirabelle-charcoal-sheet-mask',
#  '/products/within-sunscreen',
#  '/products/hillary-cleansing-oil-tamanu-jojoba-oil',
#  '/products/cute-press-calming-cica-sleeping-mask',
#  '/products/nivea-men-sensitive-shaving',
#  '/products/ceramid-cream',
#  '/products/bilka-aqua-naturals',
#  '/products/clinique-acne-solutions-tm-clinical-clearing-gel',
#  '/products/beauty-bakerie-spray-your-grace-baking-spray-setting-spray',
#  '/products/sprouts-aloe-conditioner',
#  '/products/asda-toner',
#  '/products/gentle-rose-rose-youth-elixir',
#  '/products/skin-aqua-sarafit',
#  '/products/cetaphil-pro-acne-prone-oil-free-facial-moisturising-lotion',
#  '/products/dezi-skin-skin-so-balm',
#  '/products/divi-shampoo',
#  '/products/dzintars-retinol',
#  '/products/libra-cosmetica-therapy-retinol',
#  '/products/rustic-art-shampoo',
#  '/products/sos-serum',
#  '/products/roxanne-rizzo-bronzing-mist',
#  '/products/niod-non-acid-acid-precursor-15',
#  '/products/baby-botanicals-moisturizing-baby-lotion',
#  '/products/make-over-hydration-serum-serum',
#  '/products/the-body-shop-strawberry-body-polish',
#  '/products/revolution-skincare-turmeric-serum',
#  '/products/aloe-vera-australia-aloe-skin-hair-gel',
#  '/products/cerave-acne-control-cleanser',
#  '/products/facile-lip-jelly',
#  '/products/lavera-hydro-tuchmaske',
#  '/products/oxy-anti-pimple-mark',
#  '/products/veet-hair-removal-cream-normal-skin',
#  '/products/omnia-skin-lab-skin-saviour-mist',
#  '/products/epionce-daily-shield-tinted-spf-50',
#  '/products/mielle-pomegranate-honey-curl-defining-mousse',
#  '/products/medik8-c-tetra-eye-serum',
#  '/products/one-two-free-bronzy-glow-leg-beautifier',
#  '/products/amanda-harrington-face-mist-illuminating-bronzing-mist-2',
#  '/products/dior-lash',
#  '/products/ogx-shampoo-thick-full-biotin-collagen',
#  '/products/joico-moisture-recovery-treatment-balm-for-coarse-thick-dry-hair',
#  '/products/laurel-honey-berry-mask-2',
#  '/products/bella-lash-lash-cleanser',
#  '/products/attitude-pimple-control-facewash',
#  '/products/sidmool-eco-soothing-ceramide-cream',
#  '/products/salty-face-gradual-face-tan',
#  '/products/honeststory-mineral-sunscreen',
#  '/products/b3-brazilian-bond-builder',
#  '/products/cocosolis-spf-30',
#  '/products/the-body-shop-japanese-matcha-tea-pollution-clearing-mask',
#  '/products/clasco-teron-cream',
#  '/products/dr-sheths-mineral-sunscreen',
#  '/products/honey-cleanser',
#  '/products/medik8-c-tetra-r-cream',
#  '/products/tatcha-the-kissu-lip-treatment',
#  '/products/shea-moisture-raw-shea-butter-restorative-detangler',
#  '/products/bond-bar-bonding-concentrate',
#  '/products/maruderm-bha-tonik',
#  '/products/aloe-vera-australia-aloe-vera-hair-booster',
#  '/products/rare-beauty-liquid-touch-weightless-foundation',
#  '/products/dew-it-spf-lip',
#  '/products/glutera-acne-cream',
#  '/products/rosa-graf-chamomile-paste',
#  '/products/cetaphil-lotion',
#  '/products/sana-soy-milk-q10-milk-lotion',
#  '/products/mebo-scar-ointment',
#  '/products/steli-pure',
#  '/products/aestura-vita-c-radiance-sunscreen-spf-50-pa',
#  '/products/redken-acidic-bonding-concentrate',
#  '/products/farmona-nivelazione-sensitive-care',
#  '/products/nature-spell-pure-glycerine',
#  '/products/pyunkang-yul-balancing-gel',
#  '/products/bioaqua-hair-removal',
#  '/products/slakken-snail-gel',
#  '/products/clinique-foundationalmost-powder-makeup',
#  '/products/vitamin-serum-vitamin-c-face-serum',
#  '/products/dermazinc-cream',
#  '/products/beauty-bay-hair-density-hair-serum',
#  '/products/wardah-lightening-night-cream',
#  '/products/trust-my-sister-foam-shampoo-high-porosity-hair',
#  '/products/mane-club-voodoo-oil-weightless-hair-oil',
#  '/products/svr-sebiaclear-mat-pores',
#  '/products/cerave-sa-lotion-for-rough-bumpy-skin-canada',
#  '/products/wardah-lightening-bb-cream',
#  '/products/ziaja-baby-baby-and-kids-cream',
#  '/products/zuii-organic-certified-organic-flora-liquid-foundation',
#  '/products/skinowl-eye-3',
#  '/products/rare-beauty-soft-pinch-matte-bouncy-blush',
#  '/products/tresor-rare-ultimate-pearl-creamy-cleansing-milk',
#  '/products/epionce-renewal-eye-cream',
#  '/products/somethinc-salmon-dna-marine-collagen-elixir',
#  '/products/heritage-store-hot-springs-sulfur-soap',
#  '/products/aestura-lotion-md',
#  '/products/olay-ultra-moisture-body-wash',
#  '/products/pacifica-coconut-damage-mask',
#  '/products/h-e-m-scar-ai-cream',
#  '/products/vt-r5-pdrn-firming-ampoule',
#  '/products/aveda-damage-remedy-restructuring-shampoo',
#  '/products/dermamelan-treatment',
#  '/products/dettol-gentle-care',
#  '/products/yves-rocher-volume-matiere',
#  '/products/mielle-organics-moisture-rx-hawaiian-ginger-anti-breakage-shampoo',
#  '/products/bio-essence-bio-bounce-collagen-cleanser',
#  '/products/reginald-men-reginald-sunscreen',
#  '/products/bjork-berries-scrub-soap',
#  '/products/solante-tinted',
#  '/products/aveda-flax-seed-aloe-strong-hold-sculpting-gel',
#  '/products/labo-h-sebum-removal-scalp-tonic',
#  '/products/my-cosmetics-nose-pore-trips',
#  '/products/cleansing-oil-pamplemousse-cleansing-oil',
#  '/products/nivea-creme-smooth',
#  '/products/skin-helpers-skin-tone',
#  '/products/alcina-cleansing-milk',
#  '/products/the-green-beaver-company-deodorant-spray-lemon',
#  '/products/dermalogica-skin-hydrating-booster-2',
#  '/products/face-republic-cica-soothing-gel-face-body',
#  '/products/clinique-super-primer-universal-clinique',
#  '/products/prettyskin-sheet-mask-pomegranate',
#  '/products/epoch-glacial-marine-mud',
#  '/products/dermalogica-dermalogica-pure-light-spf-50-powerbright',
#  '/products/yep-lash-xl-lash-enhancing-serum',
#  '/products/margaret-dabbs-fabulous-legs-glow-leg-spray',
#  '/products/bio-essence-bio-essence-bio-water-vitamin-b5-cica-4-gel',
#  '/products/hask-argan-oil-repairing-hair-oil',
#  '/products/skkn-by-kim-toner',
#  '/products/chemist-at-play-body-lotion-for-dry-very-dry-skin',
#  '/products/only-curls-gel-fragrance-free',
#  '/products/mederma-advanced-scar-gel',
#  '/products/rausch-dry-shampoo-fresh',
#  '/products/rayendra-tinted-sunscreen',
#  '/products/la-mer-the-concentrate-siero-protettivo',
#  '/products/cureskin-lightening-day-cream',
#  '/products/himalaya-tan-removal-orange-facewash',
#  '/products/skin-labo-concentrated-shot-sensitive-skin',
#  '/products/mixsoon-mung-bean-seed-essence-2',
#  '/products/unove-deep-damage-treatment-ex',
#  '/products/kylie-baby-gentle-conditioner',
#  '/products/martial-vivot-conditioner',
#  '/products/blu-atlas-sea-salt-spray',
#  '/products/wonder-aqua-elixer',
#  '/products/arctic-fox-hair-color',
#  '/products/cetaphil-moisturiser-2',
#  '/products/madara-spf-50',
#  '/products/kluuf-cleanser',
#  '/products/sacheu-beauty-thick-skin',
#  '/products/esalon-shine-silk',
#  '/products/milk-recipe-3-in-1-hair-removal-cream',
#  '/products/mineraline-spot-treatment-gel',
#  '/products/hidrabene-retinol',
#  '/products/uriage-mineral-sunscreen',
#  '/products/redken-acidic-color-gloss-activated-glass-gloss-treatment',
#  '/products/tosowoong-glow-bean-face-cream',
#  '/products/nude-by-nature-toner',
#  '/products/etos-cleansing-oil-gel-face-gel',
#  '/products/keragen-keratin-treatment',
#  '/products/peter-thomas-roth-potent-c-niacinamide-discoloration-treatment-2',
#  '/products/thin-lizzy-mineral-foundation',
#  '/products/shiseido-tsubaki-oil-perfection-hair-oil',
#  '/products/evagloss-lightening-serum',
#  '/products/dot-key-tinted-sunscreen',
#  '/products/ciate-london-brazilian-glow-bronzing-serum',
#  '/products/skinfood-detox-charcoal-mask',
#  '/products/dcl-aha-lightening-gel',
#  '/products/olay-total-effects-7-in-1-transforming-eye-cream',
#  '/products/9wishes-rice-radiance-cream',
#  '/products/cetaphil-protetor-solar-spray-cetaphil-sun-fps-30',
#  '/products/omega-skin-lab-pigment-c-serum',
#  '/products/cv-medical-acne-mousse',
#  '/products/airnderm-sunscreen-sensitive',
#  '/products/lilac-3x-spot-lightener',
#  '/products/82e-rose-boost',
#  '/products/alca-active-care-charcoal-thick-mask',
#  '/products/aestura-a-cica-365-soft-calming-mask-pad',
#  '/products/sebamed-anti-pimple-gel',
#  '/products/shea-moisture-raw-shea-butter-restorative-conditioner',
#  '/products/sunday-riley-luna-sleeping-night-oil',
#  '/products/kaine-gel-cleanser-rosemary-relief-gel-cleanser',
#  '/products/roox-beauty-hyaluronic-acid',
#  '/products/botalab-shampoo',
#  '/products/sainsburys-little-ones-baby-soap',
#  '/products/acnelyse-tretinoin-0-05',
#  '/products/palmers-coconut-oil-formula-with-vitamin-e-amino-bonding-complex-bonding-hair-gloss',
#  '/products/prime-prometics-prime-lash',
#  '/products/alastin-inhance-post-injection-serum',
#  '/products/cjs-butter-shea-butter-balm-plus',
#  '/products/yurhersu-snail-encense',
#  '/products/olaplex-no-7-bonding-oil',
#  '/products/balea-sea-salt-spray',
#  '/products/derma-eco-balsam',
#  '/products/honest-beauty-liquid-eyeliner',
#  '/products/orania-natural-skincare-nz-spot-treatment',
#  '/products/mixsoon-bean-sun-serum',
#  '/products/abena-zinc-paste',
#  '/products/bond-bar-bonding-primer',
#  '/products/olaplex-no-5-bond-maintenance-conditioner',
#  '/products/garnier-men-power-white',
#  '/products/n-professional-gel-sunscreen',
#  '/products/innbeauty-pimple-paste',
#  '/products/prequel-scar-solutions-silicone-scar-stick',
#  '/products/be-fine-gentle-cleanser',
#  '/products/urban-care-intense-keratin-hair-care-shampoo',
#  '/products/bodyglide-body',
#  '/products/epionce-lytic-tx-2',
#  '/products/merci-handy-spot-patches',
#  '/products/annemarie-borlind-body-care-body-oil',
#  '/products/face-facts-hyaluronic-face-cream',
#  '/products/ogx-sea-salt-spray',
#  '/products/dermatouch-tinted-sunscreen',
#  '/products/clear-nose-uv-sun-serum-spf50-pa',
#  '/products/vitamin-injections-vitamin-e-everything-moisturiser',
#  '/products/curaprox-beyou-whitening-toothpaste-lemon',
#  '/products/la-vie-en-rose-brilliant-rose-cream',
#  '/products/oil-garden-moisturising-jojoba-oil',
#  '/products/equilibra-sculpting-salt-scrub',
#  '/products/aquaphor-lip-repair-stick-for-immediate-relief-coconut',
#  '/products/bougas-beauty-cleanser',
#  '/products/comprehensive-cranium-care-head-wash',
#  '/products/awaken-conditioner',
#  '/products/gold-energy-snail-synergy-gold-snail-cream',
#  '/products/rire-mask-zone-hydrogel-mask',
#  '/products/pure-simple-pure-skin-face-wash',
#  '/products/hemp-facial-oil-therapy-hemp-seed-oil-argan-oil',
#  '/products/bepanthen-balm',
#  '/products/aknicare-cream',
#  '/products/dr-drawing-salmon-d-n-a-rejuvenation-ampoule',
#  '/products/resurface-by-shani-darden-retinol-reform',
#  '/products/ponds-cucumber-cold-cream-makeup-remover-cucumber-cold-cream',
#  '/products/bond-bar-bonding-conditioner',
#  '/products/mild-by-nature-conditioner',
#  '/products/naif-cleanser',
#  '/products/dermatica-tretinoin-0-025',
#  '/products/face-n-earth-acne-face-wash',
#  '/products/gynaguard-feminine-wash',
#  '/products/xmondo-hair-super-gloss',
#  '/products/kerasys-damage-clinic-shampoo',
#  '/products/fur-silk-scrub',
#  '/products/scrunch-it-conditioner',
#  '/products/silcare-comfort-relief-leg-lotion-nappa-energy-comfort-body',
#  '/products/loli-miracle-balm',
#  '/products/alterra-glycerin-serum',
#  '/products/matte-lactic-acid-30-with-malic-acid',
#  '/products/babaria-collagen-vegan-serum',
#  '/products/cetraben-cetraben-cream',
#  '/products/glow-recipe-watermelon-glow-lip-pop',
#  '/products/the-weekend-skin-milk-me-soothing-cleansing-milk',
#  '/products/too-faced-lip-injection-extreme-lip-plumper',
#  '/products/derma-eco-nourishing-night-cream',
#  '/products/melaleuca-serum',
#  '/products/pink-armor-nail-gel',
#  '/products/curlsmith-bonding-oil',
#  '/products/clinique-line-smoothing-concealer',
#  '/products/monat-berry-refined-scrub',
#  '/products/pleasing-hand-nail-balm',
#  '/products/roseli-siqueira-elixir-eco-green',
#  '/products/le-mieux-microderm-exfoliant',
#  '/products/elements-wellness-face-wash',
#  '/products/hot-xxl-busty-booster-creme',
#  '/products/cocokind-daily-spf',
#  '/products/bielenda-lano-balm-moisturizing-lanolin-lip-balm',
#  '/products/la-mer-the-concentrate',
#  '/products/chemist-at-play-toner',
#  '/products/the-skinscience-company-carrot-seed-oil',
#  '/products/reverie-shampoo-2',
#  '/products/kate-somerville-d-scar-scar-diminishing-serum',
#  '/products/the-ordinary-magnesium-ascorbyl-phosphate-10',
#  '/products/whitelab-acne-soap',
#  '/products/foxtale-retinol',
#  '/products/cera-ve-sa-body-wash',
#  '/products/mielle-rosemary-mint-scalp-hair-strengthening-oil-2',
#  '/products/remescar-silicone-scar-stick',
#  '/products/bumble-and-bumble-curl-reactivator',
#  '/products/rare-skinfuel-age-delaying-serum',
#  '/products/skin-rocks-the-hyperpigmentation-serum',
#  '/products/moist-diane-extra-damage-repair',
#  '/products/syoss-keratin-conditioner',
#  '/products/cerave-sa-cleanser-bar-for-rough-bumpy-skin',
#  '/products/trust-my-sister-serum-for-hair-ends-high-porosity-hair',
#  '/products/olleskin-tinted-sunscreen',
#  '/products/pure-brazilian-anti-frizz-daily-leave-in-serum',
#  '/products/eelhoe-rice-toner',
#  '/products/banila-co-prime-primer',
#  '/products/shea-moisture-raw-shea-butter-moisture-retention-conditioner',
#  '/products/nemah-restorative-scar-treatment',
#  '/products/fixlite-lightening-cream',
#  ...}

# %%
def scrape_each_product(product_links:list):
    docid = 1
    all_products_json = []
    ingredients_json = []
    unique_ingredients = {}

    for link in product_links:
        prod_json = {}
        url = f"https://incidecoder.com{link}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")

        prod_json['docid'] = docid
        prod_json['product_url'] = url

        ids = ["product-title", "product-brand-title", "product-details", "product-main-image"]
        classes = ["title", "brand", "desc", "img_url"]

        for i in range(len(ids)):
            each_id = ids[i]
            each_class = classes[i]
            soup_text = soup.find(id=each_id)

            if soup_text:
                text = soup_text.get_text()
                # specifically for scraping the image
                if each_id == "product-main-image":
                    product_img = soup_text.find("img")
                    img_url = product_img["src"] if product_img else None
                    prod_json[each_class] = img_url
                # specifically for scraping description since it has some garbage strings in the middle
                elif each_id == "product-details":
                    cleaned = " ".join(text.split())
                    # 2. Remove [more] and [less] or any [word] tokens
                    cleaned = re.sub(r"\[.*?\]", "", cleaned)
                    # 3. Clean extra spaces again
                    cleaned_desc = re.sub(r"\s+", " ", cleaned).strip()
                    prod_json[each_class] = cleaned_desc

                else:
                    prod_json[each_class] = text.strip()
         # for ingredient functions
        for block in soup.find_all("div", class_="ingredlist-by-function-block"):
            # Either returns Key Ingredients or Other Ingredients
            section_title = block.find("h3")
            if not section_title:
                continue
            section_title = section_title.get_text(strip=True)

            links = block.find_all("a", class_="func-link")

            func_ids_list = []
            for a in links:
                if a.get("href"):
                    function = a.get_text(strip=True)
                    func_url = a["href"]
                    # found a new ingredient - update json
                    if function not in unique_ingredients:                        
                        r = requests.get(f"https://incidecoder.com{func_url}")
                        func_soup = BeautifulSoup(r.text, "html.parser")
                        function_desc = func_soup.find("p").get_text(strip=True)
                        ingr_json = {"func_id" : len(ingredients_json), "title":function, "desc" : function_desc}
                        unique_ingredients[function] = len(ingredients_json)
                        ingredients_json.append(ingr_json)

                    func_ids_list.append(unique_ingredients[function])
            

            if "key" in section_title.lower():
                prod_json['key_ingredient_func'] = func_ids_list
            if "other" in section_title.lower():
                prod_json['other_ingredient_func'] = func_ids_list
        
        docid += 1
        all_products_json.append(prod_json)
    return all_products_json, ingredients_json

# %% [markdown]
# ## Write to JSON

# %%
def write_json(products, ingredients):
    with open("inci_products_new.jsonl", "w", encoding="utf-8") as f:
        for product in products:
            json.dump(product, f, ensure_ascii=False)
            f.write("\n")
    
    with open("inci_ingredient_functions_new.jsonl", "w", encoding="utf-8") as f:
        for ingredient in ingredients:
            json.dump(ingredient, f, ensure_ascii=False)
            f.write("\n")

# %%
print("Scraping Product Links")

print("Statistics of Products Scraped")
print(f"Total Number of Products = {len(all_product_links)}")
# Out:
# Scraping Product Links
# Statistics of Products Scraped
# Total Number of Products = 6010

# %%
print("Building JSON products and ingredient functions")
all_products, all_ingredients = scrape_each_product(all_product_links)
# Out:
# Building JSON products and ingredient functions

# %%
print("Statistics of Product JSON and Ingredients JSON")
print(f"Total Number of Products = {len(all_products)} (must be the same as number of products scraped)")
print(f"Total Number of Ingredient Functions = {len(all_ingredients)}")

print("Writing to JSON file")
write_json(all_products, all_ingredients)
# Out:
# Statistics of Product JSON and Ingredients JSON
# Total Number of Products = 6010 (must be the same as number of products scraped)
# Total Number of Ingredient Functions = 21
# Writing to JSON file
